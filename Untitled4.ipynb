# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprakashg/hp/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # upload dataset

# %%
ipl=pd.read_csv('/content/matches.csv')
ipl
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %% [markdown]
# # data preparation

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipl.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
ipl.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
ipl.iloc[1]
# Out:
# id                                                     335983
# season                                                2007/08
# city                                               Chandigarh
# date                                               2008-04-19
# match_type                                             League
# player_of_match                                    MEK Hussey
# venue              Punjab Cricket Association Stadium, Mohali
# team1                                         Kings XI Punjab
# team2                                     Chennai Super Kings
# toss_winner                               Chennai Super Kings
# toss_decision                                             bat
# winner                                    Chennai Super Kings
# result                                                   runs
# result_margin                                            33.0
# target_runs                                             241.0
# ...

# %%
a=ipl['winner']=='Chennai Super Kings'
a.shape[a]
# Out:
# (1095,)

# %%
b=ipl['target_runs']>220
b.shape
# Out:
# (1095,)

# %%
ipl[a&b]
# Out:
#            id   season        city        date   match_type player_of_match  \
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 146    419137  2009/10     Chennai  2010-04-03       League         M Vijay
# 320    548380     2012     Chennai  2012-05-25  Qualifier 2         M Vijay
# 375    598051     2013   Hyderabad  2013-05-08       League        SK Raina
# 830   1254072     2021      Mumbai  2021-04-21       League    F du Plessis
# 973   1359498     2023   Bengaluru  2023-04-17       League       DP Conway
# 982   1359507     2023     Kolkata  2023-04-23       League       AM Rahane
# 1016  1359541     2023       Delhi  2023-05-20       League      RD Gaikwad
#
#                                            venue                team1  \
# 1     Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 146              MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# 320              MA Chidambaram Stadium, Chepauk     Delhi Daredevils
# ...

# %%
ipl['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(ipl[ipl['season']=='2024'],y='player_of_match')
# Out:
# <Axes: xlabel='count', ylabel='player_of_match'>

# %%
#ipl.info()
#ipl.columns
#ipl.describe()
#ipl.head(12)
#ipl.tail(10)
#ipl.iloc[10]
#ipl[3:20:2]
#ipl[ipl['winner']=='Chennai Super Kings']
sns.countplot(ipl[ipl['season']=='2024'],y='winner')
# Out:
# <Axes: xlabel='count', ylabel='winner'>

# %%
ipl[(ipl['winner']=="Chennai Super Kings")&(ipl['season']=='2024')]
# Out:
#            id season        city        date match_type    player_of_match  \
# 1024  1422119   2024     Chennai  2024-03-22     League  Mustafizur Rahman
# 1030  1422125   2024     Chennai  2024-03-26     League             S Dube
# 1045  1426260   2024     Chennai  2024-04-08     League          RA Jadeja
# 1052  1426267   2024      Mumbai  2024-04-14     League        M Pathirana
# 1069  1426284   2024     Chennai  2024-04-28     League         RD Gaikwad
# 1076  1426291   2024  Dharamsala  2024-05-05     League          RA Jadeja
# 1084  1426299   2024     Chennai  2024-05-12     League    Simarjeet Singh
#
#                                                   venue  \
# 1024           MA Chidambaram Stadium, Chepauk, Chennai
# 1030           MA Chidambaram Stadium, Chepauk, Chennai
# 1045           MA Chidambaram Stadium, Chepauk, Chennai
# 1052                           Wankhede Stadium, Mumbai
# 1069           MA Chidambaram Stadium, Chepauk, Chennai
# ...

# %% [markdown]
# # column filter

# %%
ipl[['season','team1','team2','winner']]
# Out:
#       season                        team1                        team2  \
# 0       2008  Royal Challengers Bangalore        Kolkata Knight Riders
# 1       2008              Kings XI Punjab          Chennai Super Kings
# 2       2008               Delhi Capitals             Rajasthan Royals
# 3       2008               Mumbai Indians  Royal Challengers Bangalore
# 4       2008        Kolkata Knight Riders          Sunrisers Hyderabad
# ...      ...                          ...                          ...
# 1090    2024                 Punjab Kings          Sunrisers Hyderabad
# 1091    2024          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092    2024  Royal Challengers Bangalore             Rajasthan Royals
# 1093    2024          Sunrisers Hyderabad             Rajasthan Royals
# 1094    2024          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                            winner
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# ...

# %%
ipl.head(20)[['season','team1','team2','player_of_match','winner']].tail(5)
# Out:
#      season                  team1                        team2  \
# 15  2007/08  Kolkata Knight Riders               Mumbai Indians
# 16  2007/08       Delhi Daredevils  Royal Challengers Bangalore
# 17  2007/08        Deccan Chargers              Kings XI Punjab
# 18  2007/08       Rajasthan Royals        Kolkata Knight Riders
# 19  2007/08    Chennai Super Kings             Delhi Daredevils
#
#    player_of_match            winner
# 15   ST Jayasuriya    Mumbai Indians
# 16      GD McGrath  Delhi Daredevils
# 17        SE Marsh   Kings XI Punjab
# 18     SA Asnodkar  Rajasthan Royals
# 19        V Sehwag  Delhi Daredevils
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('team1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
ipl.to_excel('ipl.xlsx',index=False)

# %%
ipl['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Sunrisers Hyderabad', 'Mumbai Indians',
#        'Rising Pune Supergiant', 'Kochi Tuskers Kerala', nan,
#        'Gujarat Lions', 'Punjab Kings', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
ipl['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    123
# Sunrisers Hyderabad            117
# Delhi Capitals                 115
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Gujarat Titans                  28
# Rising Pune Supergiant          27
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
ipl.replace('Delhi Daredevils','Delhi Capitals',inplace=True)
ipl.replace('Deccan Chargers','Sunrisers Hyderabad',inplace=True)
ipl.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore',inplace=True)
ipl.replace('Rising Pune Supergiants','Rising Pune Supergiant',inplace=True)
ipl.replace('Pune Warriors','Rising Pune Supergiant',inplace=True)
ipl['winner'].unique()
ipl['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    123
# Sunrisers Hyderabad            117
# Delhi Capitals                 115
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Gujarat Titans                  28
# Rising Pune Supergiant          27
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
ipl['season'].unique()
# Out:
# array(['2008', '2009', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype=object)

# %%
ipl.replace('2007/08','2007',inplace=True)
ipl.replace('2009/10','2010',inplace=True)
ipl.replace('2020/21','2020',inplace=True)
#ipl.replace(['2007/08','2008/09','2016/17'],[])
ipl['season'].unique()
# Out:
# array(['2008', '2009', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype=object)

# %%
ipl['season']=pd.to_numeric(ipl['season'])
ipl['season'].unique()
# Out:
# array([2008, 2009, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022, 2023, 2024])
